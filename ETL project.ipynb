# %% [markdown]
# <h1 style="color":"blue"> Goodreads vs. NY Times Bestsellers </h1>

# %% [markdown]
# PROPOSAL:
#
# Datasets:
# New York Time Bestsellers: https://www.kaggle.com/dhruvildave/new-york-times-best-sellers?select=bestsellers.csv
# Goodreads:
# https://www.kaggle.com/jealousleopard/goodreadsbooks
#
# We will be extracting CSV data from the NYT Bestsellers dataset and a dataset from Goodreads and combining into a single database using ISBN-13 as a primary key.
#
# We will transform and clean the data in Pandas, removing any duplicates within the same dataset and verifying character length fields prior to loading into the database.
#
# The result in a SQL relational database. Our datasets are static and will not be updated.
#
# The data between NYTime and Goodreads will allow a user to view reader ratings and popularity, book length, the price of the book, length of time on the bestseller list, and a link to purchase.

# %% [markdown]
# We will be creating 6 tables in a Books_DB database from the Goodreads and NYTimes data.
# These tables will contain information on titles that are common between the datasets.
# Our tables will be:
# - Publisher Data
# - Author Data
# - Bestseller List Data
# - Reader Review Data
# - Sales Data
# - Book Data

# %%
# Importing necessary modules
import pandas as pd
from sqlalchemy import create_engine

# %%
# Loading NYTimes bestsellers CSV as DataFrame
bestsellers_file = "Resources/bestsellers.csv"
bestsellers_df = pd.read_csv(bestsellers_file)
bestsellers_df.dtypes
# Out:
# published_date         object
# list_name              object
# list_name_encoded      object
# rank                    int64
# isbn13                 object
# isbn10                 object
# title                  object
# author                 object
# description            object
# amazon_product_url     object
# price                 float64
# weeks_on_list           int64
# dtype: object

# %%
# Loading Goodreads CSV as DataFrame
books_file = "Resources/book.csv"
books_df = pd.read_csv(books_file, sep=",")
books_df.dtypes
# Out:
# bookID                  int64
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                float64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %%
# Renaming ISBN column to ISBN10 to match NYTimes DF, as we will be joining on this field
books_clean = books_df.rename(columns = {'isbn': 'isbn10'})
books_clean.dtypes
# Out:
# bookID                  int64
# title                  object
# authors                object
# average_rating        float64
# isbn10                 object
# isbn13                float64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %%
# Creating a DF of publisher data for the Publisher Tabler
publisher_df = books_df[["publisher"]].copy()
publisher_df.head()
# Out:
#          publisher
# 0  Scholastic Inc.
# 1  Scholastic Inc.
# 2       Scholastic
# 3  Scholastic Inc.
# 4       Scholastic

# %%
# Create a unique DataFrame of publishers with an unique ID
publisher_unique = pd.DataFrame(publisher_df.drop_duplicates('publisher').reset_index())
publisher_unique.head()
# Out:
#    index        publisher
# 0      0  Scholastic Inc.
# 1      2       Scholastic
# 2      5     Nimble Books
# 3      7   Gramercy Books
# 4      8    Del Rey Books

# %%
# Renaming columns
publisher_rename = publisher_unique.rename(columns = { "index": "id", "publisher": "publisher_name"})
publisher_rename
# Out:
#          id          publisher_name
# 0         0         Scholastic Inc.
# 1         2              Scholastic
# 2         5            Nimble Books
# 3         7          Gramercy Books
# 4         8           Del Rey Books
# ...     ...                     ...
# 2285  11094          Folio histoire
# 2286  11101      Alfaguara Infantil
# 2287  11107                    Suma
# 2288  11109  Panamericana Editorial
# 2289  11111      Editorial Presença
#
# [2290 rows x 2 columns]

# %% [markdown]
# # Why do a merge?
#
# We merged the data from the Goodreads and NYTimes Bestseller list in order to create a database containing books that exist on both lists. Our "Books" table contains information from both datasets.
#
# This will allow users to view books that have bestseller and goodreads information to analyze reader reviews vs critical acclaim.

# %%
# Merging the cleaned Goodreads dataframe and the Bestsellers dataframe on the ISBN10 data that exists in both datasets.
books_joined_df = pd.merge(books_clean, bestsellers_df, how="inner", on="isbn10")
books_joined_df
# Out:
#       bookID                                            title_x  \
# 0          2  Harry Potter and the Order of the Phoenix (Har...
# 1          2  Harry Potter and the Order of the Phoenix (Har...
# 2        865                                      The Alchemist
# 3        865                                      The Alchemist
# 4        865                                      The Alchemist
# ...      ...                                                ...
# 1046   44187  The Sea of Monsters (Percy Jackson and the Oly...
# 1047   44187  The Sea of Monsters (Percy Jackson and the Oly...
# 1048   44187  The Sea of Monsters (Percy Jackson and the Oly...
# 1049   44187  The Sea of Monsters (Percy Jackson and the Oly...
# 1050   44187  The Sea of Monsters (Percy Jackson and the Oly...
#
#                                        authors  average_rating      isbn10  \
# 0                   J.K. Rowling/Mary GrandPré            4.49   439358078
# 1                   J.K. Rowling/Mary GrandPré            4.49   439358078
# 2     Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86    61122416
# 3     Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86    61122416
# 4     Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86    61122416
# ...                                        ...             ...         ...
# 1046                              Rick Riordan            4.24  1423103343
# 1047                              Rick Riordan            4.24  1423103343
# 1048                              Rick Riordan            4.24  1423103343
# 1049                              Rick Riordan            4.24  1423103343
# 1050                              Rick Riordan            4.24  1423103343
#
#           isbn13_x language_code    num_pages  ratings_count  \
# 0     9.780440e+12           eng          870        2153167
# 1     9.780440e+12           eng          870        2153167
# 2     9.780060e+12           eng          197        1631221
# 3     9.780060e+12           eng          197        1631221
# 4     9.780060e+12           eng          197        1631221
# ...            ...           ...          ...            ...
# 1046  9.781420e+12           eng          280          10551
# 1047  9.781420e+12           eng          280          10551
# 1048  9.781420e+12           eng          280          10551
# 1049  9.781420e+12           eng          280          10551
# 1050  9.781420e+12           eng          280          10551
#
#       text_reviews_count  ...                list_name  \
# 0                  29221  ...             Series Books
# 1                  29221  ...             Series Books
# 2                  55843  ...  Trade Fiction Paperback
# 3                  55843  ...  Trade Fiction Paperback
# 4                  55843  ...  Trade Fiction Paperback
# ...                  ...  ...                      ...
# 1046                1205  ...             Series Books
# 1047                1205  ...             Series Books
# 1048                1205  ...             Series Books
# 1049                1205  ...             Series Books
# 1050                1205  ...             Series Books
#
#             list_name_encoded rank     isbn13_y  \
# 0                series-books    2  9.78044E+12
# 1                series-books    3  9.78044E+12
# 2     trade-fiction-paperback    4  9.78006E+12
# 3     trade-fiction-paperback    5  9.78006E+12
# 4     trade-fiction-paperback    5  9.78006E+12
# ...                       ...  ...          ...
# 1046             series-books    2  9.78142E+12
# 1047             series-books    2  9.78142E+12
# 1048             series-books    1  9.78142E+12
# 1049             series-books    3  9.78142E+12
# 1050             series-books    4  9.78142E+12
#
#                             title_y        author  \
# 0                      HARRY POTTER    JK Rowling
# 1                      HARRY POTTER    JK Rowling
# 2                     THE ALCHEMIST  Paulo Coelho
# 3                     THE ALCHEMIST  Paulo Coelho
# 4                     THE ALCHEMIST  Paulo Coelho
# ...                             ...           ...
# 1046  PERCY JACKSON & THE OLYMPIANS  Rick Riordan
# 1047  PERCY JACKSON & THE OLYMPIANS  Rick Riordan
# 1048  PERCY JACKSON & THE OLYMPIANS  Rick Riordan
# 1049  PERCY JACKSON & THE OLYMPIANS  Rick Riordan
# 1050  PERCY JACKSON & THE OLYMPIANS  Rick Riordan
#
#                                             description  \
# 0        A wizard hones his skills while fighting evil.
# 1     A wizard hones his conjuring skills in the ser...
# 2     In this fable, a Spanish shepherd boy ventures...
# 3     In this fable, a Spanish shepherd boy ventures...
# 4     In this fable, a Spanish shepherd boy ventures...
# ...                                                 ...
# 1046  Children of the gods battle mythological monst...
# 1047                    Battling mythological monsters.
# 1048  Children of the gods battle mythological monst...
# 1049       Children of the gods fight monsters of myth.
# 1050      Children of the gods battle monsters of myth.
#
#                                      amazon_product_url price weeks_on_list
# 0     https://www.amazon.com/Harry-Potter-And-Order-...   0.0           264
# 1     https://www.amazon.com/Harry-Potter-And-Order-...   0.0           330
# 2     https://www.amazon.com/Alchemist-Paulo-Coelho/...   0.0           255
# 3     https://www.amazon.com/Alchemist-Paulo-Coelho/...   0.0           263
# 4     https://www.amazon.com/Alchemist-Paulo-Coelho/...   0.0           264
# ...                                                 ...   ...           ...
# 1046  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.0           142
# 1047  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.0           146
# 1048  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.0           148
# 1049  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.0           175
# 1050  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.0           176
#
# [1051 rows x 23 columns]

# %%
# Removing duplicate ISBNs from merged dataframe
books_dropped = books_joined_df.drop_duplicates('isbn10')
len(books_dropped)
# Out:
# 29

# %%
books_dropped
# Out:
#       bookID                                            title_x  \
# 0          2  Harry Potter and the Order of the Phoenix (Har...
# 2        865                                      The Alchemist
# 56      1845                                      Into the Wild
# 155     1898  Into Thin Air: A Personal Account of the Mount...
# 160     2199  Team of Rivals: The Political Genius of Abraha...
# 181     2612  The Tipping Point: How Little Things Can Make ...
# 272     2767            A People's History of the United States
# 274     3869                            A Brief History of Time
# 308     4588                Extremely Loud and Incredibly Close
# 320     6149                                            Beloved
# 322     6708  The Power of Now: A Guide to Spiritual Enlight...
# 374     7445                                   The Glass Castle
# 552     7581  The Book of Awakening: Having the Life You Wan...
# 558     9516  Persepolis: The Story of a Childhood (Persepol...
# 612     9789  A Walk in the Woods: Rediscovering America on ...
# 617     9791  A Walk in the Woods: Rediscovering America on ...
# 618    15806                                   The Lovely Bones
# 627    16130                                 Alexander Hamilton
# 714    19501                                    Eat  Pray  Love
# 762    23774            Something Borrowed (Darcy & Rachel  #1)
# 765    28187  The Lightning Thief (Percy Jackson and the Oly...
# 825    29800  Scott Pilgrim  Volume 1: Scott Pilgrim's Preci...
# 894    30071  The Walking Dead  Book One (The Walking Dead #...
# 951    33313  Kitchen Confidential: Adventures in the Culina...
# 974    35805            The Capture (Guardians of Ga'Hoole  #1)
# 975    39020  1491: New Revelations of the Americas Before C...
# 992    40102      Blink: The Power of Thinking Without Thinking
# 996    43641                                Water for Elephants
# 1045   44187  The Sea of Monsters (Percy Jackson and the Oly...
#
#                                                 authors  average_rating  \
# 0                            J.K. Rowling/Mary GrandPré            4.49
# 2              Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86
# 56                                         Jon Krakauer            3.98
# 155                                        Jon Krakauer            4.17
# 160                                Doris Kearns Goodwin            4.28
# 181                                    Malcolm Gladwell            3.97
# 272                                         Howard Zinn            4.08
# 274                                     Stephen Hawking            4.17
# 308                                Jonathan Safran Foer            3.98
# 320                                       Toni Morrison            3.83
# 322                                       Eckhart Tolle            4.13
# 374                                     Jeannette Walls            4.27
# 552                                           Mark Nepo            4.31
# 558                        Marjane Satrapi/Mattias Ripa            4.25
# 612                                         Bill Bryson            4.06
# 617                                         Bill Bryson            4.06
# 618                                        Alice Sebold            3.81
# 627                                         Ron Chernow            4.23
# 714                                   Elizabeth Gilbert            3.55
# 762                                        Emily Giffin            3.85
# 765                                        Rick Riordan            4.25
# 825                                  Bryan Lee O'Malley            4.17
# 894   Robert Kirkman/Tony Moore/Charlie Adlard/Cliff...            4.35
# 951                                    Anthony Bourdain            4.07
# 974                                       Kathryn Lasky            3.90
# 975                                     Charles C. Mann            4.02
# 992                                    Malcolm Gladwell            3.93
# 996                                          Sara Gruen            4.09
# 1045                                       Rick Riordan            4.24
#
#           isbn10      isbn13_x language_code    num_pages  ratings_count  \
# 0      439358078  9.780440e+12           eng          870        2153167
# 2       61122416  9.780060e+12           eng          197        1631221
# 56     385486804  9.780390e+12           eng          207         800349
# 155    385494785  9.780390e+12           eng          368         351406
# 160    743270754  9.780740e+12           eng          916         133840
# 181    316346624  9.780320e+12           eng          301         633037
# 272     60838655  9.780060e+12           eng          729         167321
# 274    553380168  9.780550e+12           eng          212         239652
# 308    618711651  9.780620e+12           eng          326         335477
# 320   1400033411  9.781400e+12           eng          324         282045
# 322   1577314808  9.781580e+12           eng          229         159883
# 374   074324754X  9.780740e+12           eng          288         808656
# 552   1573241172  6.452410e+11           eng          438           5495
# 558   037571457X  9.780380e+12           eng          153         144121
# 612    767902521  9.780770e+12           eng          284           4315
# 617    307279464  9.780310e+12           eng          397         308840
# 618    316168815  9.780320e+12         en-US          328           5945
# 627    143034758  9.780140e+12           eng          818          97099
# 714    143038419  9.780140e+12           eng          368        1362264
# 762    312321198  9.780310e+12         en-US          322          24522
# 765    786838655  9.780790e+12           eng          375        1766725
# 825   1932664084  9.781930e+12           eng          168         155863
# 894   1582406197  9.781580e+12           eng          304          34751
# 951     60899220  9.780060e+12           eng          312         183882
# 974    439405572  9.780440e+12           eng          222          22125
# 975   1400032059  9.781400e+12           eng          541          56290
# 992    316010669  9.780320e+12           eng          296         437507
# 996   1565125606  9.781570e+12           eng          335        1260027
# 1045  1423103343  9.781420e+12           eng          280          10551
#
#       text_reviews_count  ...                             list_name  \
# 0                  29221  ...                          Series Books
# 2                  55843  ...               Trade Fiction Paperback
# 56                 18198  ...  Expeditions Disasters and Adventures
# 155                11701  ...  Expeditions Disasters and Adventures
# 160                 6118  ...                  Paperback Nonfiction
# 181                11898  ...              Paperback Business Books
# 272                 4711  ...                  Paperback Nonfiction
# 274                 5860  ...                  Paperback Nonfiction
# 308                19241  ...               Trade Fiction Paperback
# 320                 9004  ...               Trade Fiction Paperback
# 322                 7012  ...       Religion Spirituality and Faith
# 374                46176  ...                  Paperback Nonfiction
# 552                  295  ...                      Paperback Advice
# 558                 8131  ...               Paperback Graphic Books
# 612                  532  ...                                Travel
# 617                14993  ...                  Paperback Nonfiction
# 618                  735  ...                 Mass Market Paperback
# 627                 6149  ...  Combined Print and E-Book Nonfiction
# 714                47620  ...                  Paperback Nonfiction
# 762                 4032  ...               Trade Fiction Paperback
# 765                47951  ...                          Series Books
# 825                 3267  ...               Paperback Graphic Books
# 894                 1346  ...               Hardcover Graphic Books
# 951                 9427  ...                  Paperback Nonfiction
# 974                 1232  ...                          Series Books
# 975                 3238  ...                  Indigenous Americans
# 992                12937  ...                  Paperback Nonfiction
# 996                52759  ...               Trade Fiction Paperback
# 1045                1205  ...                          Series Books
#
#                          list_name_encoded rank     isbn13_y  \
# 0                             series-books    2  9.78044E+12
# 2                  trade-fiction-paperback    4  9.78006E+12
# 56    expeditions-disasters-and-adventures    1  9.78039E+12
# 155   expeditions-disasters-and-adventures    3  9.78039E+12
# 160                   paperback-nonfiction    5  9.78074E+12
# 181               paperback-business-books    5  9.78032E+12
# 272                   paperback-nonfiction    4  9.78006E+12
# 274                   paperback-nonfiction    5  9.78055E+12
# 308                trade-fiction-paperback    5  9.78062E+12
# 320                trade-fiction-paperback    2   9.7814E+12
# 322        religion-spirituality-and-faith    2  9.78158E+12
# 374                   paperback-nonfiction    5  9.78074E+12
# 552                       paperback-advice    1  9.78157E+12
# 558                paperback-graphic-books    1  9.78038E+12
# 612                                 travel    5  9.78077E+12
# 617                   paperback-nonfiction    3  9.78031E+12
# 618                  mass-market-paperback    4  9.78032E+12
# 627   combined-print-and-e-book-nonfiction    5  9.78014E+12
# 714                   paperback-nonfiction    3  9.78014E+12
# 762                trade-fiction-paperback    4  9.78031E+12
# 765                           series-books    4  9.78079E+12
# 825                paperback-graphic-books    2  9.78193E+12
# 894                hardcover-graphic-books    5  9.78158E+12
# 951                   paperback-nonfiction    1  9.78006E+12
# 974                           series-books    5  9.78044E+12
# 975                   indigenous-americans    5   9.7814E+12
# 992                   paperback-nonfiction    5  9.78032E+12
# 996                trade-fiction-paperback    2  9.78157E+12
# 1045                          series-books    3  9.78142E+12
#
#                                                 title_y  \
# 0                                          HARRY POTTER
# 2                                         THE ALCHEMIST
# 56                                        INTO THE WILD
# 155                                       INTO THIN AIR
# 160                                      TEAM OF RIVALS
# 181                                       TIPPING POINT
# 272   A PEOPLE'S HISTORY OF THE UNITED STATES: 1492 ...
# 274                             A BRIEF HISTORY OF TIME
# 308                 EXTREMELY LOUD AND INCREDIBLY CLOSE
# 320                                             BELOVED
# 322                                    THE POWER OF NOW
# 374                                    THE GLASS CASTLE
# 552                               THE BOOK OF AWAKENING
# 558                                          PERSEPOLIS
# 612                                 A WALK IN THE WOODS
# 617                                 A WALK IN THE WOODS
# 618                                    THE LOVELY BONES
# 627                                  ALEXANDER HAMILTON
# 714                                     EAT, PRAY, LOVE
# 762                                  SOMETHING BORROWED
# 765                       PERCY JACKSON & THE OLYMPIANS
# 825                 SCOTT PILGRIM: PRECIOUS LITTLE LIFE
# 894                            THE WALKING DEAD, BOOK 1
# 951                                KITCHEN CONFIDENTIAL
# 974                               GUARDIANS OF GA’HOOLE
# 975                                                1491
# 992                                               BLINK
# 996                                 WATER FOR ELEPHANTS
# 1045                      PERCY JACKSON & THE OLYMPIANS
#
#                                              author  \
# 0                                        JK Rowling
# 2                                      Paulo Coelho
# 56                                     Jon Krakauer
# 155                                    Jon Krakauer
# 160                            Doris Kearns Goodwin
# 181                                Malcolm Gladwell
# 272                                     Howard Zinn
# 274                                 Stephen Hawking
# 308                            Jonathan Safran Foer
# 320                                   Toni Morrison
# 322                                   Eckhart Tolle
# 374                                 Jeannette Walls
# 552                                       Mark Nepo
# 558                                 Marjane Satrapi
# 612                                     Bill Bryson
# 617                                     Bill Bryson
# 618                                    Alice Sebold
# 627                                     Ron Chernow
# 714                               Elizabeth Gilbert
# 762                                    Emily Giffin
# 765                                    Rick Riordan
# 825                              Bryan Lee O’Malley
# 894   Robert Kirkman, Tony Moore and Charlie Adlard
# 951                                Anthony Bourdain
# 974                                   Kathryn Lasky
# 975                                  Charles C Mann
# 992                                Malcolm Gladwell
# 996                                      Sara Gruen
# 1045                                   Rick Riordan
#
#                                             description  \
# 0        A wizard hones his skills while fighting evil.
# 2     In this fable, a Spanish shepherd boy ventures...
# 56    A man's obsession with the wilderness ends in ...
# 155   A chronicle of the 1996 Mount Everest expediti...
# 160            The political genius of Abraham Lincoln.
# 181   How and why certain products and ideas become ...
# 272   An account from the point of view of women, Af...
# 274   The British cosmologist reviews efforts to cre...
# 308   A precocious boy goes on a scavenger hunt thro...
# 320   Winner of the 1988 Pulitzer Prize for fiction....
# 322   A guide to personal growth and spiritual enlig...
# 374   The author recalls a bizarre childhood during ...
# 552   A year’s worth of daily reflections and words ...
# 558   This graphic-novel memoir chronicles the autho...
# 612     Rediscovering America on the Appalachian Trail.
# 617   A journey to rediscover America by trekking th...
# 618   A girl looks down from heaven as she describes...
# 627   A biography of the first Treasury secretary, a...
# 714   A writer’s yearlong journey in search of self ...
# 762   A maid of honor to her charmed friend, Rachel ...
# 765                     Battling mythological monsters.
# 825   Meet Scott Pilgrim, twentysomething slacker, m...
# 894   This hardcover collection features the first 1...
# 951   A memoir-exposé of the restaurant world. Origi...
# 974     Owls are the wise guides in this fantasy world.
# 975   A portrait of pre-Columbian life in the Americas.
# 992               Instinct in the workings of the mind.
# 996   A young man — and an elephant — save a Depress...
# 1045                    Battling mythological monsters.
#
#                                      amazon_product_url  price weeks_on_list
# 0     https://www.amazon.com/Harry-Potter-And-Order-...   0.00           264
# 2     https://www.amazon.com/Alchemist-Paulo-Coelho/...   0.00           255
# 56    https://www.amazon.com/Into-Wild-Jon-Krakauer-...   0.00             0
# 155   https://www.amazon.com/Into-Thin-Air-Personal-...   0.00             0
# 160   https://www.amazon.com/Team-Rivals-Political-A...  21.00            38
# 181   https://www.amazon.com/The-Tipping-Point-Littl...   0.00             0
# 272   https://www.amazon.com/Peoples-History-United-...  18.95             1
# 274   https://www.amazon.com/Brief-History-Time-Step...   0.00             2
# 308   https://www.amazon.com/Extremely-Loud-Incredib...  14.95             2
# 320   https://www.amazon.com/Beloved-Toni-Morrison/d...   0.00             1
# 322   https://www.amazon.com/The-Power-Now-Spiritual...   0.00             0
# 374   https://www.amazon.com/The-Glass-Castle-A-Memo...  15.00           161
# 552   https://www.amazon.com/The-Book-Awakening-Havi...  18.95             2
# 558   https://www.amazon.com/Persepolis-Childhood-Pa...  13.95             1
# 612   https://www.amazon.com/Walk-Woods-Rediscoverin...   0.00             0
# 617   https://www.amazon.com/Walk-Woods-Rediscoverin...   0.00           100
# 618   https://www.amazon.com/The-Lovely-Bones-Alice-...   7.99            11
# 627   https://www.amazon.com/Alexander-Hamilton-Ron-...   0.00             1
# 714   https://www.amazon.com/Eat-Pray-Love-Everythin...  15.00           153
# 762   https://www.amazon.com/Something-Borrowed-Emil...  14.99             5
# 765   https://www.amazon.com/Titans-Curse-Percy-Jack...   0.00           180
# 825   https://www.amazon.com/Scott-Pilgrim-Vol-Pilgr...  11.95             4
# 894   https://www.amazon.com/The-Walking-Dead-Book-O...  29.99             9
# 951   https://www.amazon.com/Kitchen-Confidential-Up...   0.00            36
# 974   https://www.amazon.com/Guardians-GaHoole-Captu...   0.00             3
# 975   https://www.amazon.com/1491-Revelations-Americ...   0.00             0
# 992   https://www.amazon.com/Blink-The-Power-Thinkin...  15.99           114
# 996   https://www.amazon.com/Water-Elephants-Sara-Gr...  13.95           104
# 1045  https://www.amazon.com/Titans-Curse-Percy-Jack...   0.00           128
#
# [29 rows x 23 columns]

# %%
books_joined_df.columns
# Out:
# Index(['bookID', 'title_x', 'authors', 'average_rating', 'isbn10', 'isbn13_x',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher', 'published_date', 'list_name',
#        'list_name_encoded', 'rank', 'isbn13_y', 'title_y', 'author',
#        'description', 'amazon_product_url', 'price', 'weeks_on_list'],
#       dtype='object')

# %%
# Creating a dataframe with only needed columns
books_db_df = books_joined_df[['isbn10', 'title_x', 'description', 'language_code', 'published_date', '  num_pages', 'author', 'publisher']]

# %%
# Renaming columns for readability
books_renamed = books_db_df.rename(columns = {'  num_pages': 'num_pages', 'title_x': 'title', 'language_code': 'language'})
books_renamed.columns
# Out:
# Index(['isbn10', 'title', 'description', 'language', 'published_date',
#        'num_pages', 'author', 'publisher'],
#       dtype='object')

# %%
# books_df.rename(columns={'isbn': 'isbn10'}, inplace=True)

# %%
#selecting desired columns for sales and review dataframes
col_sales= ['isbn10','price', 'amazon_product_url']
col_review= ['isbn10','average_rating','ratings_count','text_reviews_count']
#creating a dataframe with the columns
df_review = books_df[col_review]
sales_df = bestsellers_df[col_sales]
df_sales.dtypes
df_sales = sales_df.dropna(subset = ['isbn10'])

# %%
# selecting desired columns for bestseller list dataframe
best_sellers = bestsellers_df[['isbn10', 'list_name', 'rank', 'weeks_on_list']]

# dropping rows with no ISBN
best_sellers_df = best_sellers.dropna(subset = ['isbn10'])
best_sellers_df.head()
# Out:
#       isbn10      list_name  rank  weeks_on_list
# 0  316036242  Chapter Books     1              1
# 1  439023483  Chapter Books     2             67
# 2  439023491  Chapter Books     3             16
# 3  763644102  Chapter Books     4             15
# 4  385738935  Chapter Books     5              2

# %%
# selecting desired columns for author dataframe
author_df = books_df[['authors']]
author_df.head()
# Out:
#                       authors
# 0  J.K. Rowling/Mary GrandPré
# 1  J.K. Rowling/Mary GrandPré
# 2                J.K. Rowling
# 3  J.K. Rowling/Mary GrandPré
# 4  J.K. Rowling/Mary GrandPré

# %%
# Create a unique DataFrame of authors with an unique ID

author_unique = pd.DataFrame(author_df.drop_duplicates('authors').reset_index())
author_unique.head()
# Out:
#    index                     authors
# 0      0  J.K. Rowling/Mary GrandPré
# 1      2                J.K. Rowling
# 2      5      W. Frederick Zimmerman
# 3      7               Douglas Adams
# 4     10   Douglas Adams/Stephen Fry

# %%
# Renaming columns for readability

author_rename = author_unique.rename(columns = { "index": "id", "authors":"author"})

# %%
# Joining on author name in order to add author_id into books dataframe

books_authorid_df = pd.merge(books_renamed, author_rename, how="outer", on="author")
books_authorid_df
books_author = books_authorid_df.rename(columns={"id":"author_id", "publisher":"publisher_name"})
books_author
# Out:
#          isbn10                                              title  \
# 0     439358078  Harry Potter and the Order of the Phoenix (Har...
# 1     439358078  Harry Potter and the Order of the Phoenix (Har...
# 2      61122416                                      The Alchemist
# 3      61122416                                      The Alchemist
# 4      61122416                                      The Alchemist
# ...         ...                                                ...
# 7664        NaN                                                NaN
# 7665        NaN                                                NaN
# 7666        NaN                                                NaN
# 7667        NaN                                                NaN
# 7668        NaN                                                NaN
#
#                                             description language  \
# 0        A wizard hones his skills while fighting evil.      eng
# 1     A wizard hones his conjuring skills in the ser...      eng
# 2     In this fable, a Spanish shepherd boy ventures...      eng
# 3     In this fable, a Spanish shepherd boy ventures...      eng
# 4     In this fable, a Spanish shepherd boy ventures...      eng
# ...                                                 ...      ...
# 7664                                                NaN      NaN
# 7665                                                NaN      NaN
# 7666                                                NaN      NaN
# 7667                                                NaN      NaN
# 7668                                                NaN      NaN
#
#      published_date  num_pages  \
# 0         8/21/2011      870.0
# 1          8/2/2015      870.0
# 2         6/16/2013      197.0
# 3         8/11/2013      197.0
# 4         8/18/2013      197.0
# ...             ...        ...
# 7664            NaN        NaN
# 7665            NaN        NaN
# 7666            NaN        NaN
# 7667            NaN        NaN
# 7668            NaN        NaN
#
#                                                  author   publisher_name  \
# 0                                            JK Rowling  Scholastic Inc.
# 1                                            JK Rowling  Scholastic Inc.
# 2                                          Paulo Coelho    HarperCollins
# 3                                          Paulo Coelho    HarperCollins
# 4                                          Paulo Coelho    HarperCollins
# ...                                                 ...              ...
# 7664                                 Mario Vargas Llosa              NaN
# 7665  C.S. Lewis/Margarita E. Valdes/Gemma Gallart/P...              NaN
# 7666                       C.S. Lewis/Ana Falcão Bastos              NaN
# 7667        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos              NaN
# 7668  William T. Vollmann/Larry McCaffery/Michael He...              NaN
#
#       author_id
# 0           NaN
# 1           NaN
# 2         426.0
# 3         426.0
# 4         426.0
# ...         ...
# 7664    11107.0
# 7665    11110.0
# 7666    11111.0
# 7667    11112.0
# 7668    11118.0
#
# [7669 rows x 9 columns]

# %%
# Joining on publisher name in order to add publisher_id into books dataframe

books_publisherid = pd.merge(books_author, publisher_rename, how="inner", on="publisher_name")

books_ids = books_publisherid.rename(columns={"id":"publisher_id"})
books_ids
# Out:
#           isbn10                                              title  \
# 0      439358078  Harry Potter and the Order of the Phoenix (Har...
# 1      439358078  Harry Potter and the Order of the Phoenix (Har...
# 2       61122416                                      The Alchemist
# 3       61122416                                      The Alchemist
# 4       61122416                                      The Alchemist
# ...          ...                                                ...
# 1046  1565125606                                Water for Elephants
# 1047  1565125606                                Water for Elephants
# 1048  1565125606                                Water for Elephants
# 1049  1565125606                                Water for Elephants
# 1050  1565125606                                Water for Elephants
#
#                                             description language  \
# 0        A wizard hones his skills while fighting evil.      eng
# 1     A wizard hones his conjuring skills in the ser...      eng
# 2     In this fable, a Spanish shepherd boy ventures...      eng
# 3     In this fable, a Spanish shepherd boy ventures...      eng
# 4     In this fable, a Spanish shepherd boy ventures...      eng
# ...                                                 ...      ...
# 1046  Distraught after the death of his parents in a...      eng
# 1047  Distraught after the death of his parents in a...      eng
# 1048  Distraught after the death of his parents in a...      eng
# 1049  Distraught after the death of his parents in a...      eng
# 1050  Distraught after the death of his parents in a...      eng
#
#      published_date  num_pages        author   publisher_name  author_id  \
# 0         8/21/2011      870.0    JK Rowling  Scholastic Inc.        NaN
# 1          8/2/2015      870.0    JK Rowling  Scholastic Inc.        NaN
# 2         6/16/2013      197.0  Paulo Coelho    HarperCollins      426.0
# 3         8/11/2013      197.0  Paulo Coelho    HarperCollins      426.0
# 4         8/18/2013      197.0  Paulo Coelho    HarperCollins      426.0
# ...             ...        ...           ...              ...        ...
# 1046      7/24/2011      335.0    Sara Gruen  Algonquin Books    10700.0
# 1047      7/31/2011      335.0    Sara Gruen  Algonquin Books    10700.0
# 1048       8/7/2011      335.0    Sara Gruen  Algonquin Books    10700.0
# 1049      8/14/2011      335.0    Sara Gruen  Algonquin Books    10700.0
# 1050      8/21/2011      335.0    Sara Gruen  Algonquin Books    10700.0
#
#       publisher_id
# 0                0
# 1                0
# 2              284
# 3              284
# 4              284
# ...            ...
# 1046          1318
# 1047          1318
# 1048          1318
# 1049          1318
# 1050          1318
#
# [1051 rows x 10 columns]

# %%
#Dropping duplicates ISBNs after merge
books_semifinal = books_ids.drop_duplicates('isbn10')
len(books_semifinal)
# Out:
# 29

# %% [markdown]
# # ...and this is when we discovered...
# The Goodreads dataset of 11k unique rows and the NYTimes Bestsellers dataset of 8.1k unique rows, only 29 books existed on both lists.
# 🤯🤯🤯
# The Goodreads dataset that we are using is incomplete, and therefore most of the books on the NYTiems Bestseller list did not exist in the Goodreads dataset.

# %%
# Define our dataframe that will be used to create the Books table in our database, with only the necessary columns.
books_final = books_semifinal[['isbn10', 'title', 'description', 'language', 'published_date', 'publisher_id', 'num_pages', 'author_id']]
books_final
# Out:
#           isbn10                                              title  \
# 0      439358078  Harry Potter and the Order of the Phoenix (Har...
# 2       61122416                                      The Alchemist
# 56     385486804                                      Into the Wild
# 155    385494785  Into Thin Air: A Personal Account of the Mount...
# 160    307279464  A Walk in the Woods: Rediscovering America on ...
# 161    743270754  Team of Rivals: The Political Genius of Abraha...
# 182    316346624  The Tipping Point: How Little Things Can Make ...
# 273    316010669      Blink: The Power of Thinking Without Thinking
# 277    316168815                                   The Lovely Bones
# 286     60838655            A People's History of the United States
# 288    553380168                            A Brief History of Time
# 322    618711651                Extremely Loud and Incredibly Close
# 334   1400033411                                            Beloved
# 336   1400032059  1491: New Revelations of the Americas Before C...
# 353   1577314808  The Power of Now: A Guide to Spiritual Enlight...
# 405   074324754X                                   The Glass Castle
# 583   1573241172  The Book of Awakening: Having the Life You Wan...
# 589   037571457X  Persepolis: The Story of a Childhood (Persepol...
# 643    767902521  A Walk in the Woods: Rediscovering America on ...
# 648    143034758                                 Alexander Hamilton
# 735    143038419                                    Eat  Pray  Love
# 783    312321198            Something Borrowed (Darcy & Rachel  #1)
# 786    786838655  The Lightning Thief (Percy Jackson and the Oly...
# 846   1423103343  The Sea of Monsters (Percy Jackson and the Oly...
# 852   1932664084  Scott Pilgrim  Volume 1: Scott Pilgrim's Preci...
# 921   1582406197  The Walking Dead  Book One (The Walking Dead #...
# 978     60899220  Kitchen Confidential: Adventures in the Culina...
# 1001   439405572            The Capture (Guardians of Ga'Hoole  #1)
# 1002  1565125606                                Water for Elephants
#
#                                             description language  \
# 0        A wizard hones his skills while fighting evil.      eng
# 2     In this fable, a Spanish shepherd boy ventures...      eng
# 56    A man's obsession with the wilderness ends in ...      eng
# 155   A chronicle of the 1996 Mount Everest expediti...      eng
# 160   A journey to rediscover America by trekking th...      eng
# 161            The political genius of Abraham Lincoln.      eng
# 182   How and why certain products and ideas become ...      eng
# 273               Instinct in the workings of the mind.      eng
# 277   A girl looks down from heaven as she describes...    en-US
# 286   An account from the point of view of women, Af...      eng
# 288   The British cosmologist reviews efforts to cre...      eng
# 322   A precocious boy goes on a scavenger hunt thro...      eng
# 334   Winner of the 1988 Pulitzer Prize for fiction....      eng
# 336   A portrait of pre-Columbian life in the Americas.      eng
# 353   A guide to personal growth and spiritual enlig...      eng
# 405   The author recalls a bizarre childhood during ...      eng
# 583   A year’s worth of daily reflections and words ...      eng
# 589   This graphic-novel memoir chronicles the autho...      eng
# 643     Rediscovering America on the Appalachian Trail.      eng
# 648   A biography of the first Treasury secretary, a...      eng
# 735   A writer’s yearlong journey in search of self ...      eng
# 783   A maid of honor to her charmed friend, Rachel ...    en-US
# 786                     Battling mythological monsters.      eng
# 846                     Battling mythological monsters.      eng
# 852   Meet Scott Pilgrim, twentysomething slacker, m...      eng
# 921   This hardcover collection features the first 1...      eng
# 978   A memoir-exposé of the restaurant world. Origi...      eng
# 1001    Owls are the wise guides in this fantasy world.      eng
# 1002  A young man — and an elephant — save a Depress...      eng
#
#      published_date  publisher_id  num_pages  author_id
# 0         8/21/2011             0      870.0        NaN
# 2         6/16/2013           284      197.0      426.0
# 56        12/7/2014           361      207.0      566.0
# 155       11/1/2015           361      368.0      566.0
# 160      10/11/2015           361      397.0       12.0
# 161      11/11/2012           141      916.0      682.0
# 182        7/3/2011           180      301.0      664.0
# 273        1/3/2010           180      296.0      664.0
# 277        1/3/2010           180      328.0      218.0
# 286       2/14/2010           106      729.0      832.0
# 288      12/21/2014           276      212.0      645.0
# 322       1/15/2012           266      326.0     1300.0
# 334       8/25/2019            54      324.0     1497.0
# 336        3/1/2015            54      541.0        NaN
# 353        9/7/2014          1890      229.0     1890.0
# 405       1/31/2010           101      288.0     2060.0
# 583       1/30/2011          2095      438.0     2095.0
# 589        2/3/2013           132      153.0     2587.0
# 643        8/2/2015            12      284.0       12.0
# 648      11/29/2015            91      818.0     4471.0
# 735       1/24/2010          1236      368.0     5407.0
# 783       5/22/2011           964      322.0     6300.0
# 786        1/2/2011          7309      375.0     7307.0
# 846        1/3/2010          7309      280.0     7307.0
# 852       4/18/2010           304      168.0        NaN
# 921       12/5/2010          7790      304.0        NaN
# 978       6/24/2018          8645      312.0      537.0
# 1001     10/10/2010           593      222.0     1956.0
# 1002       2/6/2011          1318      335.0    10700.0

# %%
# Creating our engine for PostGRES database
rds_connection_string = "postgres:vfr4MKO)@localhost:5432/books_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirming our tables in the Books_DB
engine.table_names()

# %%
# Loading our Publisher data into the publisher table
publisher_rename.to_sql(name='publisher', con=engine, if_exists='append', index=False)

# %%
# Loading our author data into the author table
author_rename.to_sql(name='author', con=engine, if_exists='append', index=False)

# %%
# Loading our books data into the books table
books_final.to_sql(name='book', con=engine, if_exists='append', index=False)

# %%
# Loading our bestseller data into the bestseller table
best_sellers_df.to_sql(name='bestseller_list', con=engine, if_exists='append', index=False)

# %%
# Loading our reviews data into the reviews table
df_review.to_sql(name='review', con=engine, if_exists='append', index=False)

# %%
# Loading our sales data into the sales table
df_sales.to_sql(name='sales', con=engine, if_exists='append', index=False)

# %%
conn = engine.connect()

# %% [markdown]
# # Using the Database

# %% [markdown]
# Finding all books published by HarperCollins.

# %%
# Find books with the same publisher
books_publisher = pd.read_sql("select * from book join publisher on book.publisher_id = publisher.id where publisher_name = 'HarperCollins'", conn)
books_publisher
# Out:
#      isbn10          title                                        description  \
# 0  61122416  The Alchemist  In this fable, a Spanish shepherd boy ventures...
#
#   language published_date  publisher_id  num_pages  author_id   id  \
# 0      eng     2013-06-16           284        197        426  284
#
#   publisher_name
# 0  HarperCollins

# %% [markdown]
# Finding all books with non-sequential runs on the Science bestsellers list.

# %%
# Find books on the 'Science' bestseller list with non-sequential runs
science_bestsellers = pd.read_sql("select book.title  from book join bestseller_list on book.isbn10 = bestseller_list.isbn10 WHERE list_name = 'Science' GROUP BY bestseller_list.isbn10, book.title HAVING COUNT(*) > 1", conn)
science_bestsellers
# Out:
#                      title
# 0  A Brief History of Time
